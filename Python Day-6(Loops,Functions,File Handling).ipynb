# %% [markdown]
# # LOOPS:

# %% [markdown]
# ![Screenshot 2025-08-25 193638.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-08-25 194109.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-08-25 194213.png](data:image/png;base64,...)

# %% [markdown]
# ## Loops & Iteration:

# %%
# Ex- Check whether a number is even or odd

x = 101

if x%2 == 0:
  print("Even")
else:
  print("odd")
# Out:
# odd

# %%
x = int(input("Enter your number:"))

if x % 2 == 0:
  print("Even")
else:
  print("odd")
# Out:
# Enter your number:13
# odd

# %%
## Iterationg over a list of integers:

# %%
list_1 = [10,20,40,50,70]

for i in list_1:
  print(i)
# Out:
# 10
# 20
# 40
# 50
# 70

# %%
## Iterationg over a string:

# %%
str_1 = "Odisha"
for ch in str_1:
    print(ch)
# Out:
# O
# d
# i
# s
# h
# a

# %%
## Iterate over a dictionary:

# %%
students_data = {1: ['Sam', 25], 2:['Sharma',28], 3:['Ravi',22], 4:['Sid',23], 5:['Varun',24]}

for key, val in students_data.items():
    print(key, val)
# Out:
# 1 ['Sam', 25]
# 2 ['Sharma', 28]
# 3 ['Ravi', 22]
# 4 ['Sid', 23]
# 5 ['Varun', 24]

# %%
## Iterate over a range of values:

# %%
for i in range(1,5): # last one is not included
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## List Comprehention:

# %%
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

list_2 = []

for i in list_1:
    list_2.append(i)

print(list_2)
# Out:
# ['Automobiles', 'Honda', 'Benz', 'Maruti', 'Kia']

# %%
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

list_2 = []

for i in list_1:
  list_2.append(len(i))
print(list_2)
# Out:
# [11, 5, 4, 6, 3]

# %%
# Same as the previous one:
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

list_2 = [len(i) for i in list_1]

print(list_2)
# Out:
# [11, 5, 4, 6, 3]

# %%
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

d = {}

for i in list_1:
  d[i] = len(i)
print(d)
# Out:
# {'Automobiles': 11, 'Honda': 5, 'Benz': 4, 'Maruti': 6, 'Kia': 3}

# %%
# Same as the previous one:
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

d = {i: len(i) for i in list_1}

d
# Out:
# {'Automobiles': 11, 'Honda': 5, 'Benz': 4, 'Maruti': 6, 'Kia': 3}
